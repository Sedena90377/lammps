# %%
x= open("Al2.txt")
t1=[]
for i in range(1,105):
    t=[]
    y=x.readline()
    for i in y:
        t.append(i)
    #print(t)
    for i in t:
        if i==' ':
            y1=str()
            #print(y,t.index(i))
            q=t.index(i)
            for i in range(q,len(t)-2):
                y1+=t[i]
            t1.append(y1)
            print(str(y1))
#print(t1)
# Out:
#  Time-averaged data for fix 4
#  Time-averaged data for fix 4
#  Time-averaged data for fix 4
#  Time-averaged data for fix 4
#  Time-averaged data for fix 4
#  TimeStep Number-of-row
#  TimeStep Number-of-row
#  Row c_rdf2[1
#  Row c_rdf2[1
#  10
#  0.03182
#  0.09547
#  0.15912
#  0.22277
#  0.28642
#  0.35007
#  0.41372
#  0.47737
#  0.54102
#  0.60467
#  0.66832
#  0.73197
#  0.79562
#  0.85927
#  0.92292
#  0.98657
#  1.0502
#  1.1138
#  1.1775
#  1.2411
#  1.3048
#  1.3684
#  1.4321
#  1.4957
#  1.5594
#  1.6230
#  1.6867
#  1.7503
#  1.8140
#  1.8776
#  1.9413
#  2.0049
#  2.0686
#  2.1322
#  2.1959
#  2.2595
#  2.3232
#  2.3868
#  2.4505
#  2.5141
#  2.5778
#  2.6414
#  2.7051
#  2.7687
#  2.8324
#  2.8960
#  2.9597
#  3.0233
#  3.0870
#  3.1506
#  3.2143
#  3.2779
#  3.3416
#  3.4052
#  3.4689
#  3.5325
#  3.5962
#  3.6598
#  3.7235
#  3.7871
#  3.8508
#  3.9144
#  3.9781
#  4.0417
#  4.1054
#  4.1690
#  4.2327
#  4.2963
#  4.3600
#  4.4236
#  4.4873
#  4.5509
#  4.6146
# ...
